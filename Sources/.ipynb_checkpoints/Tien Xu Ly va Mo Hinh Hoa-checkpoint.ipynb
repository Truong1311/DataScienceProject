# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.neural_network import MLPRegressor,MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import set_config
set_config(display='diagram')

# %%
data_df = pd.read_csv('data02.csv')
data_df
# Out:
#                                  Name                          Screen  \
# 0         Xiaomi POCO M3 - Chính hãng        IPS LCD, 6.53", Full HD+
# 1          Xiaomi Mi 11 128Gb Ram 8Gb   AMOLED, 6.81", Quad HD+ (2K+)
# 2     Oppo Reno5 8GB/128GB chính hãng                 6,43 inch, OLED
# 3       Redmi Note 9 Pro 5G 6Gb/128Gb
# 4        iPhone SE Cũ 16Gb Nguyên Bản             IPS LCD, 4.0", DVGA
# ...                               ...                             ...
# 1416             Masstel HAPI 10 Fami                 IPS LCD, 5", HD
# 1417                  Itel Alpha Lite              TFT LCD, 5", FWVGA
# 1418                  Masstel X5 Fami             IPS LCD, 5.45", HD+
# 1419                       Mobell P41           IPS LCD, 5.5", FWVGA+
# 1420                       Mobell S41                  LCD, 5", FWVGA
#
#                                                     Cpu  \
# 0                                 Snapdragon 662 8 nhân
# 1                                 Snapdragon 888 (5 nm)
# 2                Qualcomm SM7125 Snapdragon 720G (8 nm)
# 3     Octa-core (2x2.2 GHz Kryo 570 & 6x1.8 GHz Kryo...
# 4                                              Apple A9
# ...                                                 ...
# 1416                             MediaTek MT6739 4 nhân
# 1417                          Spreadtrum SC7731E 4 nhân
# 1418                          Spreadtrum SC7731E 4 nhân
# 1419                            MediaTek MT6580A 4 nhân
# 1420                            MediaTek MT6580M 4 nhân
#
#                               MainCamera SelfieCamera         Rom    Ram  \
# 0           Chính 48 MP & Phụ 2 MP, 2 MP          8MP   128/64 GB    4GB
# 1         Chính 108 MP & Phụ 13 MP, 5 MP        20 MP      128 GB   8 GB
# 2     Chính 64 MP & Phụ 8 MP, 2 MP, 2 MP         44MP      128 GB   8 GB
# 3                Chính 108MP+8MP+2MP+2MP         16MP      128 GB    6GB
# 4                                  12 MP       1.2 MP       16 GB   2 GB
# ...                                  ...          ...         ...    ...
# 1416                                5 MP         5 MP       16 GB   2 GB
# 1417                                5 MP         2 MP        8 GB   1 GB
# 1418                                8 MP         5 MP        8 GB   1 GB
# 1419                                5 MP         2 MP        8 GB   1 GB
# 1420                                5 MP         2 MP        8 GB   1 GB
#
#                             Pin  Price
# 0                       6000mAh      1
# 1               Li-Ion 4600 mAh      3
# 2     4.310 mAh + Sạc nhanh 50W      2
# 3                Li-Po 4820 mAh      2
# 4                Li-Po 1624 mAh      1
# ...                         ...    ...
# 1416                   2000 mAh      1
# 1417                   2050 mAh      1
# 1418                   3200 mAh      1
# 1419                   3500 mAh      1
# 1420                   2200 mAh      1
#
# [1421 rows x 9 columns]

# %%
data_df.isna().sum()
# Out:
# Name             0
# Screen           0
# Cpu             49
# MainCamera      26
# SelfieCamera     7
# Rom              5
# Ram              5
# Pin             44
# Price            0
# dtype: int64

# %%
data_df.shape
# Out:
# (1421, 9)

# %% [markdown]
# ### Tách các tập.

# %%
# Tách X và y
y = data_df["Price"]
X = data_df.drop("Price", axis=1)

# %%
y
# Out:
# 0       1
# 1       3
# 2       2
# 3       2
# 4       1
#        ..
# 1416    1
# 1417    1
# 1418    1
# 1419    1
# 1420    1
# Name: Price, Length: 1421, dtype: int64

# %%
X
# Out:
#                                  Name                          Screen  \
# 0         Xiaomi POCO M3 - Chính hãng        IPS LCD, 6.53", Full HD+
# 1          Xiaomi Mi 11 128Gb Ram 8Gb   AMOLED, 6.81", Quad HD+ (2K+)
# 2     Oppo Reno5 8GB/128GB chính hãng                 6,43 inch, OLED
# 3       Redmi Note 9 Pro 5G 6Gb/128Gb
# 4        iPhone SE Cũ 16Gb Nguyên Bản             IPS LCD, 4.0", DVGA
# ...                               ...                             ...
# 1416             Masstel HAPI 10 Fami                 IPS LCD, 5", HD
# 1417                  Itel Alpha Lite              TFT LCD, 5", FWVGA
# 1418                  Masstel X5 Fami             IPS LCD, 5.45", HD+
# 1419                       Mobell P41           IPS LCD, 5.5", FWVGA+
# 1420                       Mobell S41                  LCD, 5", FWVGA
#
#                                                     Cpu  \
# 0                                 Snapdragon 662 8 nhân
# 1                                 Snapdragon 888 (5 nm)
# 2                Qualcomm SM7125 Snapdragon 720G (8 nm)
# 3     Octa-core (2x2.2 GHz Kryo 570 & 6x1.8 GHz Kryo...
# 4                                              Apple A9
# ...                                                 ...
# 1416                             MediaTek MT6739 4 nhân
# 1417                          Spreadtrum SC7731E 4 nhân
# 1418                          Spreadtrum SC7731E 4 nhân
# 1419                            MediaTek MT6580A 4 nhân
# 1420                            MediaTek MT6580M 4 nhân
#
#                               MainCamera SelfieCamera         Rom    Ram  \
# 0           Chính 48 MP & Phụ 2 MP, 2 MP          8MP   128/64 GB    4GB
# 1         Chính 108 MP & Phụ 13 MP, 5 MP        20 MP      128 GB   8 GB
# 2     Chính 64 MP & Phụ 8 MP, 2 MP, 2 MP         44MP      128 GB   8 GB
# 3                Chính 108MP+8MP+2MP+2MP         16MP      128 GB    6GB
# 4                                  12 MP       1.2 MP       16 GB   2 GB
# ...                                  ...          ...         ...    ...
# 1416                                5 MP         5 MP       16 GB   2 GB
# 1417                                5 MP         2 MP        8 GB   1 GB
# 1418                                8 MP         5 MP        8 GB   1 GB
# 1419                                5 MP         2 MP        8 GB   1 GB
# 1420                                5 MP         2 MP        8 GB   1 GB
#
#                             Pin
# 0                       6000mAh
# 1               Li-Ion 4600 mAh
# 2     4.310 mAh + Sạc nhanh 50W
# 3                Li-Po 4820 mAh
# 4                Li-Po 1624 mAh
# ...                         ...
# 1416                   2000 mAh
# 1417                   2050 mAh
# 1418                   3200 mAh
# 1419                   3500 mAh
# 1420                   2200 mAh
#
# [1421 rows x 8 columns]

# %% [markdown]
# - Tách tập Train, Validation và Test với tỉ lệ 60:20:20

# %%
# tách tập train(train và val) và tập test với tỉ lệ 80:20
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# từ tập train tách ra tập train và tập validation với tỉ lệ 75:25 để ứng với 60:20 ở tập dữ liệu ban đâu.
tr_X, val_X, tr_y, val_y = train_test_split(train_X, train_y, test_size=0.25, random_state=0)

# %%
# tập train( dùng để huấn luyện)
tr_X.shape
# Out:
# (852, 8)

# %%
val_X.shape
# Out:
# (284, 8)

# %%
test_X.shape
# Out:
# (285, 8)

# %%
tr_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 852 entries, 1414 to 745
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          852 non-null    object
#  1   Screen        852 non-null    object
#  2   Cpu           824 non-null    object
#  3   MainCamera    842 non-null    object
#  4   SelfieCamera  847 non-null    object
#  5   Rom           849 non-null    object
#  6   Ram           849 non-null    object
#  7   Pin           827 non-null    object
# dtypes: object(8)
# memory usage: 59.9+ KB

# %%
tr_y
# Out:
# 1414    1
# 1379    1
# 112     2
# 636     1
# 1312    4
#        ..
# 201     1
# 990     2
# 595     1
# 229     3
# 745     1
# Name: Price, Length: 852, dtype: int64

# %% [markdown]
# ### Quan sát dữ liệu từ tập tr_X( tập huấn luyện) nhân thấy:
#  - Ở thuôc tính Name có thể tách ra hãng sản xuất, do thực tế có thể thấy rằng, mỗi hãng khác nhau sẽ có giá bán khác nhau.
#  - Các thuộc tính Screen, Main Camera, Selfie Camera, Ram, Rom và Pin có thể tách lấy các giá trị dạng số bằng với :
#      + Screen: lấy kích thước màn hình( đơn vị inchs).
#      + Main Camera, Selfie Camera: lấy giá trị độ phân giải của camera chính.( đối với giá trị có nhiều giá trị, ví dụ:Chính 48 MP & Phụ 8 MP, 2 MP, 2 MP, thì chỉ lấy giá trị camera chính.
#      + Đối với Ram và Rom xử lí chuỗi bình thường.
#  - Thuộc tính CPU có thể tách ra loại chip: ví dụ: Qualcomm Snapdragon, MediaTek, Exynos, ... Nhưng trên thị trường có quá nhiều phiên bản khác nhau của chip nên sẽ bỏ qua cột dữ liệu này :((

# %% [markdown]
# - Class ColAdderDropper sẽ xử lý thuộc tính Name của dữ liệu, thay thế thuộc tính Name bằng thuốc tính Phone Maker, chỉ ra rằng giá trị của thuộc tính này là hãng điện thoại.

# %%
# xóa cột Name và thêm cột Phone Maker, xóa cột Cpu
class ColAdderDropper(BaseEstimator, TransformerMixin):
    def __init__(self, num_top_pmakers=1):
        self.num_top_pmakers = num_top_pmakers
    def fit(self, tr_X, y=None):
        pmakers_col = pd.Series([name.split()[0].upper() for name in tr_X.Name])
        self.pmaker_counts_ = pmakers_col.value_counts()
        pmakers = list(self.pmaker_counts_.index)
        self.top_pmakers_ = pmakers[:max(1, min(self.num_top_pmakers, len(pmakers)))]
        return self
    def transform(self, X_df, y=None):
        name = X_df.Name
        df = X_df.drop(["Cpu","Name"], axis = 1)
        Pmakers = []
        for val in name:
            pmaker = 'OTHERS'
            for p in self.top_pmakers_:
                if p in val.upper():
                    pmaker = p
                    break
            Pmakers.append(pmaker)
        df['PhoneMaker'] = pd.Series(Pmakers, index = df.index)
        return df

# %%
col_adderdropper = ColAdderDropper(num_top_pmakers=10)
col_adderdropper.fit(tr_X)
print(col_adderdropper.pmaker_counts_)
print()
print(col_adderdropper.top_pmakers_)
# Out:
# XIAOMI        133
# SAMSUNG       127
# IPHONE        121
# OPPO           73
# VIVO           43
# REALME         38
# VSMART         34
# SONY           28
# ASUS           26
# BLACKBERRY     26
# HTC            23
# NOKIA          19
# LENOVO         17
# SKY            13
# MOTOROLA       12
# LG             12
# PHILIPS        12
# GIONEE         11
# SHARP          11
# HUAWEI          8
# MASSGO          7
# GOOGLE          6
# KYOCERA         6
# WIKO            6
# ĐIỆN            4
# ONEPLUS         4
# NOMI            3
# INFINIX         3
# TECNO           3
# MEIZU           3
# ITEL            2
# INFOCUS         2
# OBI             2
# PANTECH         2
# KASHI           1
# MASSTEL         1
# ENERGIZER       1
# HP              1
# ANOKA           1
# CAT             1
# REDMI           1
# MOBELL          1
# MÁY             1
# LEAGOO          1
# NUBIA           1
# "MEIZU          1
# dtype: int64
#
# ['XIAOMI', 'SAMSUNG', 'IPHONE', 'OPPO', 'VIVO', 'REALME', 'VSMART', 'SONY', 'ASUS', 'BLACKBERRY']

# %%
col_adderdropper.transform(tr_X)
# Out:
#                                                  Screen  \
# 1414                                 IPS LCD, 5.7", HD+
# 1379                                IPS LCD, 6.47", HD+
# 112                                       6.67" IPS LCD
# 636                               6.13 inches, 93.8 cm2
# 1312                       OLED, 5.8", Super Retina XDR
# ...                                                 ...
# 201                                 IPS LCD, 4.0", DVGA
# 990                      Super LCD 3, 5.2", QuadHD (2K)
# 595    5.88 inches, 87.6 cm2 (~81.3% screen-to-body ...
# 229                            IPS LCD, 5.5", Retina HD
# 745                              IPS LCD, 5.2", Full HD
#
#                                              MainCamera  \
# 1414                                               5 MP
# 1379                 Chính 13 MP & Phụ 8 MP, 2 MP, 2 MP
# 112                                       64MP+13MP+5MP
# 636                Dual: 13 MP, PDAF 5 MP, depth sensor
# 1312                                     3 camera 12 MP
# ...                                                 ...
# 201                                              8.0 MP
# 990                                               20 MP
# 595   Dual: 12 MP (f/1.9, 1.4µm, dual-pixel PDAF, gy...
# 229                                          Dual 12 MP
# 745                                               13 MP
#
#                      SelfieCamera        Rom    Ram  \
# 1414                         5 MP      16 GB   1 GB
# 1379                         8 MP     128 GB   4 GB
# 112                          20MP     128 GB    8GB
# 636                          8 MP      32 GB   3 GB
# 1312                        12 MP     256 GB   4 GB
# ...                           ...        ...    ...
# 201                        1.2 MP   16/32 GB   1 GB
# 990                         13 MP      32 GB   3 GB
# 595   20 MP (f/2.0, 2.0µm), 1080p      64 GB   6 GB
# 229                        7.0 MP      64 GB   3 GB
# 745                        8.0 MP      16 GB   3 GB
#
#                                        Pin  PhoneMaker
# 1414                              2800 mAh      OTHERS
# 1379                              5000 mAh        VIVO
# 112                        Li-Ion 5000 mAh      XIAOMI
# 636                         Li-Po 5000 mAh     SAMSUNG
# 1312                3046 mAh, có sạc nhanh      IPHONE
# ...                                    ...         ...
# 201                         Li-Po 1510 mAh      IPHONE
# 990                         Li-Po 2700 mAh      OTHERS
# 595   Non-removable Li-Po 3120 mAh battery      XIAOMI
# 229                        Li-Ion 2691 mAh      IPHONE
# 745                        Li-Ion 2610 mAh  BLACKBERRY
#
# [852 rows x 7 columns]

# %%
# chuyển giá trị màn hình từ chuỗi sang số theo kích thước màn hình lọc được từ thông số màn hình.
# Camera trước và Selfie camera lấy theo giá trị camera chính.
### vì dữ liệu thu thập từ nhiều trang web khác nhau nên định dạng khác nhau ví dụ: 12 MP và 12MP ... Nên sẽ có 
##  một vài sai số. Nhưng tạm chấp nhận được :(((
class EncodingString(BaseEstimator, TransformerMixin):
    def __init__(self, cols = None):
        self. cols = cols
    def fit(self,X_df,y =None):
        encode = []
        for col in self.cols:
            encode.append((col,X_df[col].str.extract(r'([0-9][0-9][0-9][0-9]|[0-9][0-9][0-9]|[0-9][0-9]|[0-9][.,][0-9]|[0-9])', expand=False).str.replace(',','.')))
        self.encode = dict(encode)
        return self
    def transform(self, X_df, y=None):
        df = X_df.drop(self.cols, axis = 1)
        for col in self.cols:
            df[col] = pd.Series(pd.to_numeric(self.encode[col]), index = df.index)
        return df

# %%
cols = ["Screen","MainCamera","SelfieCamera","Rom","Ram","Pin"]
col_encoding = EncodingString(cols = cols)
col_encoding.fit(tr_X)
col_encoding.transform(tr_X)
# Out:
#                                         Name  \
# 1414                                Nokia C2
# 1379                                Vivo Y30
# 112              Xiaomi Redmi K30S 8GB/128GB
# 636            Samsung Galaxy M20 Chính Hãng
# 1312                     iPhone 11 Pro 256GB
# ...                                      ...
# 201                         iPhone 5C cũ 99%
# 990                        HTC J Butterfly 3
# 595              Xiaomi Mi 8 SE 64Gb Ram 6Gb
# 229   iPhone 8 Plus 64Gb Mới Chính Hãng VN/A
# 745             BlackBerry DTEK50 chính hãng
#
#                                          Cpu  Screen  MainCamera  \
# 1414               Spreadtrum SC9832E 4 nhân     5.7         5.0
# 1379               MediaTek Helio P35 8 nhân     6.4        13.0
# 112   Qualcomm SM8250 Snapdragon 865 (7 nm+)     6.6        64.0
# 636                              Exynos 7904     6.1        13.0
# 1312                 Apple A13 Bionic 6 nhân     5.8         3.0
# ...                                      ...     ...         ...
# 201                                 Apple A6     4.0         8.0
# 990                  Qualcomm Snapdragon 810     3.0        20.0
# 595           Qualcomm SDM710 Snapdragon 710     5.8        12.0
# 229                         Apple A11 Bionic     5.5        12.0
# 745                  Qualcomm Snapdragon 625     5.2        13.0
#
#       SelfieCamera    Rom  Ram     Pin
# 1414           5.0   16.0  1.0  2800.0
# 1379           8.0  128.0  4.0  5000.0
# 112           20.0  128.0  8.0  5000.0
# 636            8.0   32.0  3.0  5000.0
# 1312          12.0  256.0  4.0  3046.0
# ...            ...    ...  ...     ...
# 201            1.2   16.0  1.0  1510.0
# 990           13.0   32.0  3.0  2700.0
# 595           20.0   64.0  6.0  3120.0
# 229            7.0   64.0  3.0  2691.0
# 745            8.0   16.0  3.0  2610.0
#
# [852 rows x 8 columns]

# %%
df = col_encoding.fit_transform(ColAdderDropper(num_top_pmakers=7).fit_transform(tr_X))

# %%
df.select_dtypes('float').plot(kind='bar')

# %%
num_cols = ["Screen","MainCamera","SelfieCamera","Rom","Ram","Pin"]
unorder_cate_cols=["PhoneMaker"]

preprocess=ColumnTransformer(
    transformers=[
        ('nume_cols',KNNImputer(n_neighbors=5),num_cols),
        ('unorder_cate_col', OneHotEncoder(handle_unknown='ignore',sparse=False),unorder_cate_cols)],
        remainder='passthrough'
)

preprocess_pipeline=Pipeline(steps=[
    ('coladderdropper',ColAdderDropper(num_top_pmakers=7)),
    ('encodingstring',EncodingString(cols = num_cols)),
    ('preprocess',preprocess),
    ('standardscaler',StandardScaler())]
)

# %%
preprocess_pipeline
# Out:
# Pipeline(steps=[('coladderdropper', ColAdderDropper(num_top_pmakers=7)),
#                 ('encodingstring',
#                  EncodingString(cols=['Screen', 'MainCamera', 'SelfieCamera',
#                                       'Rom', 'Ram', 'Pin'])),
#                 ('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('nume_cols', KNNImputer(),
#                                                   ['Screen', 'MainCamera',
#                                                    'SelfieCamera', 'Rom', 'Ram',
#                                                    'Pin']),
#                                                  ('unorder_cate_col',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   ['PhoneMaker'])])),
#                 ('standardscaler', StandardScaler())])

# %%
preprocess_pipeline.fit_transform(tr_X)
# Out:
# array([[-0.18679174, -0.40406234, -0.16468563, ..., -0.23054726,
#         -0.20387445, -0.43009201],
#        [-0.18329212, -0.21059337, -0.10804207, ...,  4.33750545,
#         -0.20387445, -0.43009201],
#        [-0.18229222,  1.02277136,  0.11853221, ..., -0.23054726,
#         -0.20387445,  2.32508388],
#        ...,
#        [-0.18629179, -0.23477699,  0.11853221, ..., -0.23054726,
#         -0.20387445,  2.32508388],
#        [-0.18779163, -0.23477699, -0.12692326, ..., -0.23054726,
#         -0.20387445, -0.43009201],
#        [-0.18929147, -0.21059337, -0.10804207, ..., -0.23054726,
#         -0.20387445, -0.43009201]])

# %%
full_pipeline = make_pipeline(
    (preprocess_pipeline),
    #(LogisticRegression(multi_class='multinomial',max_iter=2500))
    #(MLPRegressor(hidden_layer_sizes =(20),activation='tanh',solver= 'lbfgs',max_iter=15000,random_state = 0))
    (MLPClassifier(hidden_layer_sizes=(20,), activation='tanh', solver='lbfgs', random_state=0, max_iter=15000))

)

# %%
train_errs = []
val_errs = []
alphas = [0.01,0.1, 1, 10, 100, 500, 1000]
num_top_titles_s = [1, 3, 5, 6, 8, 10,13,15,19]
activations =['identity', 'logistic', 'tanh', 'relu']
best_val_err = float('inf'); best_alpha = None; best_num_top_titles = None
for alpha in alphas:
    for num_top_titles in num_top_titles_s:
        # YOUR CODE HERE
        for act in activations:
            full_pipeline.set_params(pipeline__coladderdropper__num_top_pmakers=num_top_titles,mlpclassifier__activation=act,mlpclassifier__alpha = alpha)

            s = full_pipeline.fit(tr_X,tr_y)

            train_err = (1-s.score(tr_X,tr_y))*100
            val_err = (1-s.score(val_X,val_y))*100

            train_errs.append(train_err)
            val_errs.append(val_err)
            if val_err <= min(val_errs):
                best_alpha = alpha
                best_num_top_titles = num_top_titles
best_val_err = min(val_errs)
'Finish!'
# Out:
# C:\Users\TRUONG DANG\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:471: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\TRUONG DANG\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:471: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\TRUONG DANG\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:471: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\TRUONG DANG\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:471: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\TRUONG DANG\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:471: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\TRUONG DANG\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:471: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-dd4bfacde71a> in <module>
#       9         full_pipeline.set_params(pipeline__coladderdropper__num_top_pmakers=num_top_titles,mlpclassifier__alpha = alpha)
#      10
# ---> 11         s = full_pipeline.fit(tr_X,tr_y)
#      12
#      13         train_err = (1-s.score(tr_X,tr_y))*100
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     333             if self._final_estimator != 'passthrough':
#     334                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 335                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     336
#     337         return self
#
# ~\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in fit(self, X, y)
#    1025         self : returns a trained MLP model.
#    1026         """
# -> 1027         return self._fit(X, y, incremental=(self.warm_start and
#    1028                                             hasattr(self, "classes_")))
#    1029
#
# ~\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in _fit(self, X, y, incremental)
#     373         # Run the LBFGS solver
#     374         elif self.solver == 'lbfgs':
# --> 375             self._fit_lbfgs(X, y, activations, deltas, coef_grads,
#     376                             intercept_grads, layer_units)
#     377         return self
#
# ~\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in _fit_lbfgs(self, X, y, activations, deltas, coef_grads, intercept_grads, layer_units)
#     459             iprint = -1
#     460
# --> 461         opt_res = scipy.optimize.minimize(
#     462                 self._loss_grad_lbfgs, packed_coef_inter,
#     463                 method="L-BFGS-B", jac=True,
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     615                                   **options)
#     616     elif meth == 'l-bfgs-b':
# --> 617         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     618                                 callback=callback, **options)
#     619     elif meth == 'tnc':
#
# ~\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_and_grad(self, x)
#     198         if not np.array_equal(x, self.x):
#     199             self._update_x_impl(x)
# --> 200         self._update_fun()
#     201         self._update_grad()
#     202         return self.f, self.g
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# ~\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in _loss_grad_lbfgs(self, packed_coef_inter, X, y, activations, deltas, coef_grads, intercept_grads)
#     177         loss, coef_grads, intercept_grads = self._backprop(
#     178             X, y, activations, deltas, coef_grads, intercept_grads)
# --> 179         grad = _pack(coef_grads, intercept_grads)
#     180         return loss, grad
#     181
#
# ~\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in _pack(coefs_, intercepts_)
#      37 def _pack(coefs_, intercepts_):
#      38     """Pack the parameters into a single vector."""
# ---> 39     return np.hstack([l.ravel() for l in coefs_ + intercepts_])
#      40
#      41
#
# <__array_function__ internals> in hstack(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\shape_base.py in hstack(tup)
#     341     # As a special case, dimension 0 of 1-dimensional arrays is "horizontal"
#     342     if arrs and arrs[0].ndim == 1:
# --> 343         return _nx.concatenate(arrs, 0)
#     344     else:
#     345         return _nx.concatenate(arrs, 1)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
best_num_top_titles

# %%
min(train_errs)

# %%
val_errs

# %%
best_val_err

# %%
best_alpha

# %%
full_pipeline.set_params(pipeline__coladderdropper__num_top_pmakers=best_num_top_titles,mlpclassifier__alpha = best_alpha)

s = full_pipeline.fit(train_X,train_y)

# %%
s.predict(test_X)

# %%
s.score(test_X,test_y)

# %%
1-0.6210526315789474

# %%
s = pd.
