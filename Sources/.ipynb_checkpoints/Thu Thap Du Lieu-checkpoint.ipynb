# %%
import requests
from bs4 import BeautifulSoup
import urllib.request
import csv
import pandas as pd

# %%
Name = []
Ram = []
Rom =[]
Pin = []
Screen = []
Main_Camera = []
Selfie_Camera = []
Price =[]
i = 1
while True:
    url = f'https://didongthongminh.vn/dien-thoai/page/{i}'
    i +=1
    html_text = requests.get(url).text
    tree = BeautifulSoup(html_text, "html.parser")
    phone_list = tree.find_all('div',{'class':'dst_hproduct_hidden'})
    if len(phone_list) == 0:
        break
    for phone in phone_list:
        # Tên điện thoại.
        try:
            name = phone.find('a',{'class':'dst_hproduct_title'}).text
        except:
            name = ''
        Name.append(name)
        configuration = phone.find_all('span',{'class':'dst_cauhinh'})
        # Màn hình 
        try:
            screen = configuration[0].text[configuration[0].text.find(":")+1:]
        except:
            screen = ''
        Screen.append(screen)
        # Camera
        try:
            main_c = configuration[3].text[configuration[3].text.find("Camera:")+len("Camera:")+1:configuration[3].text.find("Selfie:")-2]
            selfie_c = configuration[3].text[configuration[3].text.find("Selfie:")+len("Selfie:")+1:]
        except:
            main_c =''
            selfie_c =''
        Main_Camera.append(main_c)
        Selfie_Camera.append(selfie_c)
        # Ram
        try:
            ram = configuration[2].text[len('Ram:'):configuration[2].text.find(',')]
        except:
            ram = ''
        Ram.append(ram)
        # Rom
        try:
            rom = configuration[2].text[configuration[2].text.rfind(':')+1:]
        except:
            rom = ''
        Rom.append(rom)
        # dung lượng Pin
        try:
            pin = configuration[4].text
        except:
            pin = ''
        Pin.append(pin)
        # giá điện thoại.
        try:
            price = phone.find('div',{'class':"dst_hproduct_price"}).text
        except:
            price = ''
        Price.append(price)
        
df = pd.DataFrame({'Name' : pd.Series(Name),
                   'Screen' : Screen,
                   'Main Camera' : Main_Camera,
                   'Selfie Camera' : Selfie_Camera,
                   'Rom' : pd.Series(Rom),
                   'Ram' : pd.Series(Ram),
                   'Pin' : pd.Series(Pin),
                   'Price': pd.Series(Price)})

# %%
df
# Out:
#                                          Name                   Screen  \
# 0               Redmi Note 9 Pro 5G 6Gb/128Gb
# 1                iPhone SE Cũ 16Gb Nguyên Bản      IPS LCD, 4.0", DVGA
# 2     Oppo Reno5Pro 8GB/128GB Hàng chính hãng    OLED, 6.55", Full HD+
# 3        Oppo Reno5 8GB/128GB Hàng chính hãng          6,43 inch, OLED
# 4           Oppo A15 3GB/32GB Hàng chính hãng      IPS LCD, 6.52", HD+
# ...                                       ...                      ...
# 1384            iPhone 6S Mới 32GB Chính Hãng        IPS LCD, 4.7", HD
# 1385            iPhone 6S Mới 16GB Chính Hãng        IPS LCD, 4.7", HD
# 1386            iPhone 6S Mới 64Gb Chính Hãng        IPS LCD, 4.7", HD
# 1387           iPhone 6 Plus Lock Cũ 16GB 99%   IPS LCD, 5.5", Full HD
# 1388           iPhone 6 Plus Lock Cũ 64GB 99%   IPS LCD, 5.5", Full HD
#
#                              Main Camera Selfie Camera      Rom    Ram  \
# 0                Chính 108MP+8MP+2MP+2MP          16MP   128 GB    6GB
# 1                                  12 MP        1.2 MP    16 GB   2 GB
# 2     Chính 64 MP & Phụ 8 MP, 2 MP, 2 MP          32MP    256GB   8 GB
# 3     Chính 64 MP & Phụ 8 MP, 2 MP, 2 MP          44MP   128 GB   8 GB
# 4           Chính 13 MP & Phụ 2 MP, 2 MP           5MP    32 GB   3 GB
# ...                                  ...           ...      ...    ...
# 1384                               12 MP        5.0 MP    32 GB   2 GB
# 1385                               12 MP        5.0 MP    16 GB   2 GB
# 1386                               12 MP        5.0 MP    64 GB   2 GB
# 1387                              8.0 MP        1.2 MP    16 GB   1 GB
# 1388                              8.0 MP        1.2 MP    64 GB   1 GB
#
#                                  Pin        Price
# 0                Pin: Li-Po 4820 mAh  6.390.000 Đ
# 1                Pin: Li-Po 1624 mAh  2.190.000 Đ
# 2                  Pin: Có sạc ngược      Liên hệ
# 3     Pin: 4.310 mAh + Sạc nhanh 50W  8.990.000 Đ
# 4                Pin: Li-Po 4230 mAh  3.290.000 Đ
# ...                              ...          ...
# 1384             Pin: Li-Po 1810 mAh  7.390.000 Đ
# 1385             Pin: Li-Po 1810 mAh  5.990.000 Đ
# 1386             Pin: Li-Po 1810 mAh  9.090.000 Đ
# 1387             Pin: Li-Po 2915 mAh  1.890.000 Đ
# 1388             Pin: Li-Po 2915 mAh  2.190.000 Đ
#
# [1389 rows x 8 columns]

# %%
export_csv = df.to_csv ('data01.csv', index = None, header=True)
